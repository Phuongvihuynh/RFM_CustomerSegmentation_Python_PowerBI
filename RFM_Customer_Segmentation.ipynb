# %% [markdown]
# Welcome to the shopping world of Istanbul! Our dataset contains shopping information from 10 different shopping malls between 2021 and 2023. We have gathered data from various age groups and genders to provide a comprehensive view of shopping habits in Istanbul. The dataset includes essential information such as invoice numbers, customer IDs, age, gender, payment methods, product categories, quantity, price, order dates, and shopping mall locations. We hope that this dataset will serve as a valuable resource for researchers, data analysts, and machine learning enthusiasts who want to gain insights into shopping trends and patterns in Istanbul. Explore the dataset and discover the fascinating world of Istanbul shopping!

# %% [markdown]
# # **Attribute Information:**
#
# * invoice_no: Invoice number. Nominal. A combination of the letter 'I' and a
#
# * 6-digit integer uniquely assigned to each operation.
#
# * customer_id: Customer number. Nominal. A combination of the letter 'C' and a 6-digit integer uniquely assigned to each operation.
#
# * gender: String variable of the customer's gender.
#
# * age: Positive Integer variable of the customers age.
#
# * category: String variable of the category of the purchased product.
#
# * quantity: The quantities of each product (item) per transaction. Numeric.
#
# * price: Unit price. Numeric. Product price per unit in Turkish Liras (TL).
#
# * payment_method: String variable of the payment method (cash, credit card or debit card) used for the transaction.
#
# * invoice_date: Invoice date. The day when a transaction was generated.
#
# * shopping_mall: String variable of the name of the shopping mall where the transaction was made.

# %% [markdown]
# # **I. Importing Necessary Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly
# from pandas_profiling import ProfileReport

# %% [markdown]
# # **II. Loading the Dataset**

# %%
df = pd.read_csv('customer_shopping_data.csv')
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # **III. EDA**

# %% [markdown]
# ## **1. Overview dataset:**

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.shape

# %%
list(df)
# Out:
# ['invoice_no',
#  'customer_id',
#  'gender',
#  'age',
#  'category',
#  'quantity',
#  'price',
#  'payment_method',
#  'invoice_date',
#  'shopping_mall']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# **Hiển thị từng giá trị và đếm số lượng của mỗi giá trị của mỗi cột**

# %%
for col in list(df.columns):
    print("\nfor column : ", col,"\n")
    print(df[col].value_counts())
# Out:
# for column :  invoice_no
#
# I138884    1
# I291671    1
# I175779    1
# I226143    1
# I683818    1
#           ..
# I319287    1
# I173400    1
# I828064    1
# I194850    1
# I232867    1
# Name: invoice_no, Length: 99457, dtype: int64
#
# for column :  customer_id
#
# C241288    1
# C116138    1
# C382765    1
# C285074    1
# C405356    1
#           ..
# C220083    1
# C286933    1
# C301304    1
# C214184    1
# C273973    1
# Name: customer_id, Length: 99457, dtype: int64
#
# for column :  gender
#
# Female    59482
# Male      39975
# Name: gender, dtype: int64
#
# for column :  age
#
# 37    2057
# 22    2051
# 64    2002
# 43    2000
# 51    1993
# 30    1981
# 24    1977
# 40    1960
# 48    1955
# 36    1954
# 38    1954
# 28    1953
# 27    1950
# 39    1947
# 21    1947
# 61    1945
# 52    1945
# 19    1936
# 56    1916
# 33    1913
# 46    1911
# 62    1909
# 44    1904
# 53    1903
# 67    1901
# 69    1901
# 23    1897
# 26    1896
# 68    1893
# 42    1892
# ...

# %% [markdown]
# ## **Kết luận chung:**
#
# - Dataset bao gồm 10 cột và 99457 dòng.
# - Gồm 3 cột (age, price, quantity) là biến số còn lại là biến phân loại.
# - Cột invoice_date bị sai kiểu dữ liệu => cần chuyển về kiểu datetime.

# %% [markdown]
# ## **2. Summary Statistics**

# %%
df.describe().T
# Out:
#             count        mean         std    min    25%    50%      75%  \
# age       99457.0   43.427089   14.990054  18.00  30.00   43.0    56.00
# quantity  99457.0    3.003429    1.413025   1.00   2.00    3.0     4.00
# price     99457.0  689.256321  941.184567   5.23  45.45  203.3  1200.32
#
#              max
# age         69.0
# quantity     5.0
# price     5250.0

# %%
df.describe(include='object').T
# Out:
#                 count unique               top   freq
# invoice_no      99457  99457           I138884      1
# customer_id     99457  99457           C241288      1
# gender          99457      2            Female  59482
# category        99457      8          Clothing  34487
# payment_method  99457      3              Cash  44447
# invoice_date    99457    797        24/11/2021    159
# shopping_mall   99457     10  Mall of Istanbul  19943

# %% [markdown]
# **Nhận xét:**
# - Có sự xuất hiện phân phối không đều, rời rạc ở cột Price => xuất hiện Outlier.

# %% [markdown]
# ## **3. Check**

# %% [markdown]
# **Phân tích mọi điểm bất thường trong dữ liệu, null, trùng lặp, outlier**

# %% [markdown]
# ### **a. Check missing values:**

# %%
df.isna().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %% [markdown]
# ### **b. Check duplicated values:**

# %%
print('Tổng số dòng: ',df.shape[0])
print('Tổng số cột: ',df.shape[1])
dupplicate_row = len(df)-len(df.drop_duplicates())
print('Số dòng bị trùng lặp: ',dupplicate_row)
# Out:
# Tổng số dòng:  99457
# Tổng số cột:  10
# Số dòng bị trùng lặp:  0

# %% [markdown]
# ### **c. Kiểm tra phân phối của dữ liệu**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Distribution of Prices')
plt.xlabel('price')
plt.ylabel('Frequency')
plt.show()

price_mean = df['price'].mean()
price_median = df['price'].median()
price_std = df['price'].std()
price_min =df['price'].min()
price_max = df['price'].max()

print(f"Mean Price: {price_mean}")
print(f"Median Price: {price_median}")
print(f"Standard Deviation of Price: {price_std}")
print(f"Minimum Price: {price_min}")
print(f"Maximum Price: {price_max}")

plt.figure(figsize=(8, 4))
sns.boxplot(x=df['price'])
plt.title('Box Plot of Prices')
plt.xlabel('price')
plt.show()

sns.kdeplot(data= df, x="price")
# Out:
# Mean Price: 689.2563209226097
# Median Price: 203.3
# Standard Deviation of Price: 941.184567215467
# Minimum Price: 5.23
# Maximum Price: 5250.0
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ## **Nhận xét chung**
# - Không có missing values
# - Không có duplicated values
# - Có xuất hiện outlier gây nhiễu ở Price => cần loại bỏ.

# %% [markdown]
# # **IV. PRECESSING DATA:**

# %% [markdown]
# ## **1. Xử lý missing value**

# %%
df.dropna(how='any', inplace=True)

# %%
df.isna().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %% [markdown]
# ## **2. Xử lý duplicated values**

# %% [markdown]
# Không có giá trị nào bị trùng lặp

# %% [markdown]
# ## **3. Xử lý Outlier biến Price**

# %%
continuous_column_list = ['price']

for column_name in continuous_column_list:
    while True:
        Q1 = df[column_name].quantile(0.25)
        Q3 = df[column_name].quantile(0.75)
        IQR = Q3 - Q1

        df_cleaned_outlier = df[~((df[column_name] < (Q1 - 1.5 * IQR)) | (df[column_name] > (Q3 + 1.5 * IQR)))]

        if len(df_cleaned_outlier) == len(df):
            break
        df = df_cleaned_outlier
print(df.shape[0])
print(df.shape[1])
# Out:
# 92411
# 10

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['price'])
plt.title('Box Plot of Prices')
plt.xlabel('price')
plt.show()

# %% [markdown]
# ## **4. Chuyển type của cột invoice_date về đúng kiểu dữ liệu datetime**

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 4    I337046     C189076  Female   53     Books         4    60.60
# 5    I227836     C657758  Female   28  Clothing         5  1500.40
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card   2022-08-05          Kanyon
# 1     Debit Card   2021-12-12  Forum Istanbul
# 2           Cash   2021-11-09       Metrocity
# 4           Cash   2021-10-24          Kanyon
# 5    Credit Card   2022-05-24  Forum Istanbul

# %% [markdown]
# # **V. Feature Engineering**

# %%
df1 = df

# %%
df1['age_group'] = df1['age'].apply(lambda x: "children" if x <= 16 else ("young_age" if 17 <= x <= 30 else ("middle_age" if 30 < x <= 45 else 'old_age')))
df1
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 4        I337046     C189076  Female   53            Books         4    60.60
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# ...          ...         ...     ...  ...              ...       ...      ...
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
# Year
df1['year'] = df1['invoice_date'].dt.strftime("%Y")
# Month
df1['month'] = df1['invoice_date'].dt.strftime("%m")
# Weekday
df1['weekday'] = df1['invoice_date'].dt.strftime("%w")
# Day
df1['day'] = df1['invoice_date'].dt.strftime("%d")
# Total Price
df1['total_price'] = df1['quantity'] * df1['price']

# %%
df1.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 4    I337046     C189076  Female   53     Books         4    60.60
# 5    I227836     C657758  Female   28  Clothing         5  1500.40
#
#   payment_method invoice_date   shopping_mall  age_group  year month weekday  \
# 0    Credit Card   2022-08-05          Kanyon  young_age  2022    08       5
# 1     Debit Card   2021-12-12  Forum Istanbul  young_age  2021    12       0
# 2           Cash   2021-11-09       Metrocity  young_age  2021    11       2
# 4           Cash   2021-10-24          Kanyon    old_age  2021    10       0
# 5    Credit Card   2022-05-24  Forum Istanbul  young_age  2022    05       2
#
#   day  total_price
# 0  05      7502.00
# 1  12      5401.53
# 2  09       300.08
# ...

# %%
df1.to_csv('sample.csv')
from google.colab import files
files.download("sample.csv")

# %% [markdown]
# # **VI. VISUALLIZATION:**

# %% [markdown]
# Vẽ chart của từng cột để trả lời cho các câu hỏi:
# 1. Về tuổi
# 2. Giới tính
# 3. Giá tiền
# ...
# * liên quan từng cột với nhau.

# %%
def distribution(dataframe, col):
    group_dt = dataframe.groupby(col).agg(total_price=('total_price', np.sum),
                                          quantity=('quantity', np.sum))
    group_dt['avg_revenue'] = group_dt['total_price'] / group_dt['quantity']
    return group_dt.reset_index()

# %% [markdown]
# ### **1. Gender columns**

# %% [markdown]
# - Giới tính nào có tỷ lệ mua hàng cao hơn?
# - Xu hướng mua sắm những mặt hàng nào theo giới tính?
# - Giới tính nào có nhiều doanh thu hơn?

# %%
df1['gender'].value_counts().plot.pie(autopct='%1.2f',figsize=(8, 8))
plt.show()

# %%
gender_dis =  distribution(df1, 'gender')
gender_dis
# Out:
#    gender  total_price  quantity  avg_revenue
# 0  Female  89205622.19    160685   555.158367
# 1    Male  60051816.97    107838   556.870648

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x ='gender' , y = 'quantity', hue = 'gender',  data = gender_dis)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x = 'gender', y = 'total_price', hue = 'gender', data = gender_dis )
plt.show()

# %% [markdown]
# ### **2. Category:**

# %%
catete_dis =  distribution(df1, 'category')
catete_dis
# Out:
#           category   total_price  quantity  avg_revenue
# 0            Books  8.345529e+05     14982    55.703704
# 1         Clothing  1.139968e+08    103558  1100.801397
# 2        Cosmetics  6.792863e+06     45465   149.408620
# 3  Food & Beverage  8.495351e+05     44277    19.186825
# 4            Shoes  1.693320e+07     12064  1403.613758
# 5         Souvenir  6.358247e+05     14871    42.756012
# 6       Technology  5.234250e+06      2985  1753.517588
# 7             Toys  3.980426e+06     30321   131.276219

# %% [markdown]
# **Tổng doanh thu:**

# %%
df_category = distribution(df1, 'category')
plt.figure(figsize=(10, 8))
sns.barplot(x='category', y='total_price', data=df_category, order=df_category.sort_values('total_price', ascending=False).category)
plt.title('Revenue by Category')
plt.xlabel('Category')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x ='category', y = 'quantity',  palette='winter_r',  data = catete_dis)
plt.show()

plt.figure(figsize=(12, 5))
sns.barplot(x ='category', y = 'avg_revenue',  palette='winter_r',  data = catete_dis)
plt.show()
# Out:
# <ipython-input-60-17834fce6ee1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ='category', y = 'quantity',  palette='winter_r',  data = catete_dis)
# <ipython-input-60-17834fce6ee1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ='category', y = 'avg_revenue',  palette='winter_r',  data = catete_dis)

# %% [markdown]
# ### **3. Age_group:**

# %%
age_group_df = distribution(df1,'age_group')
age_group_df
# Out:
#     age_group  total_price  quantity  avg_revenue
# 0  middle_age  42817292.79     77693   551.108759
# 1     old_age  68775859.50    123197   558.259207
# 2   young_age  37664286.87     67633   556.892151

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x = 'age_group', y = 'quantity', data = age_group_df)
plt.title("Quantity of age_group")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x = 'age_group', y = 'avg_revenue', data = age_group_df)
plt.title("Average revenue of each age_group")
plt.show()

# %% [markdown]
# **Tỉ lệ khách hàng trong ba năm**

# %%
grouped_data = df1.groupby(['month', 'year']).agg(count_customers=('customer_id', 'nunique'))

plt.figure(figsize=(12, 6))
sns.lineplot(data=grouped_data, x='month', y='count_customers', hue='year')


plt.title('Trend of Number of Customers by Month and Year')
plt.xlabel('Month')
plt.ylabel('Number of Customers')
plt.legend(title='Year')


plt.show()

# %%
yearr_dis =  distribution(df1, 'year')
yearr_dis
# Out:
#    year  total_price  quantity  avg_revenue
# 0  2021  68596931.80    122495   559.997811
# 1  2022  68032330.15    123146   552.452618
# 2  2023  12628177.21     22882   551.882581

# %%
yearr_dis.pivot_table(values='avg_revenue', index='year').plot(kind='bar')
plt.title('Average revenue by year')
plt.ylabel('Average revenue')
plt.show()

# %% [markdown]
# **4. Shopping mall:**

# %%
df_shoppingmall = distribution(df1, 'shopping_mall')
df_shoppingmall
# Out:
#        shopping_mall  total_price  quantity  avg_revenue
# 0        Cevahir AVM   7413509.05     13425   552.216689
# 1  Emaar Square Mall   7413183.70     13062   567.538179
# 2     Forum Istanbul   7464335.99     13390   557.456011
# 3       Istinye Park  14671351.04     26478   554.095892
# 4             Kanyon  29586930.71     53315   554.945713
# 5   Mall of Istanbul  30131859.51     53997   558.028400
# 6          Metrocity  22496543.40     40520   555.196037
# 7       Metropol AVM  15220102.91     27478   553.901409
# 8     Viaport Outlet   7369523.66     13221   557.410458
# 9       Zorlu Center   7490099.19     13637   549.248309

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x='shopping_mall', y='total_price', color="green", data=df_shoppingmall, order=df_shoppingmall.sort_values('total_price', ascending=False).shopping_mall)
plt.title('Revenue by shopping mall')
plt.xlabel('Shopping_mall')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **VII. RFM and Customer Segmentation**

# %% [markdown]
# Phân tích RFM (Lần truy cập gần đây, Tần suất, Tiền tệ) là phương pháp tiếp cận dựa trên hành vi, nhóm khách hàng thành các phân khúc. Nó nhóm các khách hàng trên cơ sở các giao dịch mua hàng trước đó của họ. Khách hàng đã mua gần đây như thế nào, tần suất như thế nào và bao nhiêu. RFM lọc khách hàng thành nhiều nhóm khác nhau nhằm mục đích phục vụ tốt hơn. Có một bộ phận khách hàng chi tiêu nhiều nhưng nếu họ chỉ mua một lần hoặc mua gần đây như thế nào thì sao? Họ có thường mua sản phẩm của chúng ta không? Ngoài ra, Nó còn giúp các nhà quản lý thực hiện một chiến dịch quảng cáo hiệu quả cho dịch vụ được cá nhân hóa.
#
# * Gần đây (R): Ai đã mua gần đây? Số ngày kể từ lần mua cuối cùng (lần mua gần đây nhất)
# * Tần suất (F): Ai đã mua thường xuyên? Nó có nghĩa là tổng số lần mua hàng. ( Tân sô cao)
# * Giá trị tiền tệ(M): Ai có số tiền mua hàng cao? Nó có nghĩa là tổng số tiền khách hàng đã chi tiêu (giá trị tiền tệ cao)

# %% [markdown]
# ## **1. Phân tích RFM:**

# %% [markdown]
# **Tìm ngày kể từ lần mua cuối cùng.**

# %%
customer_data = df1.groupby('customer_id')['invoice_date'].max().reset_index()


most_recent_date = df1['invoice_date'].max()

customer_data['Days_Since_Last_Purchase'] = (most_recent_date - customer_data['invoice_date']).dt.days

customer_data.drop(columns=['invoice_date'], inplace=True)

# %%
customer_data.head(10)
# Out:
#   customer_id  Days_Since_Last_Purchase
# 0     C100004                       467
# 1     C100005                         5
# 2     C100006                        97
# 3     C100012                       570
# 4     C100019                       591
# 5     C100025                       643
# 6     C100028                       468
# 7     C100030                       146
# 8     C100034                       579
# 9     C100041                       684

# %%
# tính tổng số giao dịch của mỗi khách hàng
total_transactions = df1.groupby('customer_id')['invoice_no'].nunique().reset_index()
total_transactions.rename(columns={'invoice_no': 'Total_Transactions'}, inplace=True)

# Tổng số sản phẩm được mua bởi khách hàng
total_products_purchased = df1.groupby('customer_id')['quantity'].sum().reset_index()
total_products_purchased.rename(columns={'quantity': 'Total_Products_Purchased'}, inplace=True)

# Gộp hai cột vừa tính thành 1 dataframe
customer_data = pd.merge(customer_data, total_transactions, on='customer_id')
customer_data = pd.merge(customer_data, total_products_purchased, on='customer_id')

customer_data.head()
# Out:
#   customer_id  Days_Since_Last_Purchase  Total_Transactions  \
# 0     C100004                       467                   1
# 1     C100005                         5                   1
# 2     C100006                        97                   1
# 3     C100012                       570                   1
# 4     C100019                       591                   1
#
#    Total_Products_Purchased
# 0                         5
# 1                         2
# 2                         3
# 3                         5
# 4                         1

# %%
df['Total_Spend'] = df1['price'] * df1['quantity']
total_spend = df.groupby('customer_id')['Total_Spend'].sum().reset_index()

# Tính giá trị giao dịch trung bình cho mỗi khách hàng
average_transaction_value = total_spend.merge(total_transactions, on='customer_id')
average_transaction_value['Average_Transaction_Value'] = average_transaction_value['Total_Spend'] / average_transaction_value['Total_Transactions']

# Hợp nhất các cột mới vào khung dữ liệu customer_data
customer_data = pd.merge(customer_data, total_spend, on='customer_id')
customer_data = pd.merge(customer_data, average_transaction_value[['customer_id', 'Average_Transaction_Value']], on='customer_id')

customer_data.head()
# Out:
#   customer_id  Days_Since_Last_Purchase  Total_Transactions  \
# 0     C100004                       467                   1
# 1     C100005                         5                   1
# 2     C100006                        97                   1
# 3     C100012                       570                   1
# 4     C100019                       591                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value
# 0                         5      7502.00                    7502.00
# 1                         2      2400.68                    2400.68
# 2                         3       322.56                     322.56
# 3                         5       130.75                     130.75
# 4                         1        35.84                      35.84

# %% [markdown]
# ### **Calculate the RF Score**

# %%
# Đánh chỉ số cho từng R _ F _ M

customer_data['recency_score'] = pd.qcut(customer_data['Days_Since_Last_Purchase'], 5, labels=[5, 4, 3, 2, 1])
customer_data['frequency_score'] = pd.qcut(customer_data['Total_Products_Purchased'].rank(method='first'), 5, labels=[1, 2, 3, 4, 5])
customer_data['monetary_score'] = pd.qcut(customer_data['Total_Spend'], 5, labels=[1, 2, 3, 4, 5])

customer_data['RF_SCORE'] = (customer_data['recency_score'].astype(str) +
                      customer_data['frequency_score'].astype(str))
customer_data.head()
# Out:
#   customer_id  Days_Since_Last_Purchase  Total_Transactions  \
# 0     C100004                       467                   1
# 1     C100005                         5                   1
# 2     C100006                        97                   1
# 3     C100012                       570                   1
# 4     C100019                       591                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                         5      7502.00                    7502.00
# 1                         2      2400.68                    2400.68
# 2                         3       322.56                     322.56
# 3                         5       130.75                     130.75
# 4                         1        35.84                      35.84
#
#   recency_score frequency_score monetary_score RF_SCORE
# 0             3               5              5       35
# 1             5               2              4       52
# ...

# %% [markdown]
# ## **2. Customer Segmentation:**

# %%
seg = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

customer_data['segment'] = customer_data['RF_SCORE'].replace(seg, regex=True)
customer_data
# Out:
#       customer_id  Days_Since_Last_Purchase  Total_Transactions  \
# 0         C100004                       467                   1
# 1         C100005                         5                   1
# 2         C100006                        97                   1
# 3         C100012                       570                   1
# 4         C100019                       591                   1
# ...           ...                       ...                 ...
# 92406     C999886                         0                   1
# 92407     C999910                       123                   1
# 92408     C999974                       302                   1
# 92409     C999976                       261                   1
# 92410     C999995                       586                   1
#
#        Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                             5      7502.00                    7502.00
# ...

# %%
customer_data.to_csv('RFM.csv')
from google.colab import files
files.download("RFM.csv")

# %%
customer_data[["segment", "Days_Since_Last_Purchase", "Total_Products_Purchased", "Total_Spend"]].groupby("segment").agg(["mean", "sum", "count"])
# Out:
#                     Days_Since_Last_Purchase                  \
#                                         mean      sum  count
# segment
# about_to_sleep                    397.673219  2913354   7326
# at_risk                           636.930874  9462882  14857
# cant_loose                        634.926843  4643220   7313
# champions                          79.484877   588665   7406
# hibernating                       635.920532  9378556  14748
# loyal_customers                   317.808790  4700392  14790
# need_attention                    396.822945  1476975   3722
# new_customers                      78.307754   290835   3714
# potential_loyalists               158.783718  2352222  14814
# promising                         239.050524   889507   3721
#
#                     Total_Products_Purchased                Total_Spend  \
#                                         mean    sum  count         mean
# segment
# ...

# %%
import plotly.express as px

fig = px.treemap(customer_data, path=[customer_data.segment],
                  color='segment',
                  color_discrete_map={
                      'hibernating': '#e74c3c',
                      'at_risk': '#e67e22',
                      'cant_loose': '#f1c40f',
                      'about_to_sleep': '#2ecc71',
                      'need_attention': '#3498db',
                      'loyal_customers': '#9b59b6',
                      'promising': '#34495e',
                      'new_customers': '#2c3e50',
                      'potential_loyalists': '#7f8c8d',
                      'champions': '#1abc9c'
                  },
                  title='Distribution of the RFM Segments')
fig.update_layout(title_text='Distribution of the RFM Segments by customer numbers', title_x=0.5,
                  title_font=dict(size=20))
fig.update_traces(textinfo="label+value+percent root", textfont =dict(size=14))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **3. Visuallization by Group**

# %% [markdown]
# **Đếm số lượng khách hàng cho từng phân khúc khách hàng.**

# %%
count_seg = customer_data['segment'].value_counts().sort_values()
count_seg
# Out:
# new_customers           3714
# promising               3721
# need_attention          3722
# cant_loose              7313
# about_to_sleep          7326
# champions               7406
# hibernating            14748
# loyal_customers        14790
# potential_loyalists    14814
# at_risk                14857
# Name: segment, dtype: int64

# %%
plt.figure(figsize = (15,10))

sns.barplot(x=count_seg.index, y = count_seg.values, color = 'green')
plt.xlabel('Group')
plt.ylabel('Number of each grop')
plt.title('Count of each grop')
plt.xticks(rotation= 0)
plt.show()

# %% [markdown]
# **Nhóm khách hàng 'at_risk' có tỷ lệ mua hàng cao nhất trong tất cả các nhóm.**
#
# - Ta cần tập trung vào những nhóm khách hàng mua hàng gần đây với tần suất cao như Champions, Loyal_customers, Potential_loyalist, Promising.

# %% [markdown]
# **Phân khúc nào khả năng chi trả cao cho mỗi đơn hàng?**

# %%
seg_spend = customer_data.groupby('segment')['Total_Spend'].sum().sort_values()
seg_spend
# Out:
# segment
# promising                833396.16
# new_customers            835193.81
# about_to_sleep          4049321.30
# need_attention          5742260.78
# hibernating             8288483.22
# potential_loyalists    17764418.47
# champions              19877451.30
# cant_loose             24389822.10
# at_risk                27472772.07
# loyal_customers        40004319.95
# Name: Total_Spend, dtype: float64

# %%
plt.figure(figsize = (15,10))

sns.barplot(x=seg_spend.index, y = seg_spend.values, color = 'green')
plt.ylabel('Total Spend')
plt.title('Total Spend of each Group')
plt.show()

# %%
customer_data.head()
# Out:
#   customer_id  Days_Since_Last_Purchase  Total_Transactions  \
# 0     C100004                       467                   1
# 1     C100005                         5                   1
# 2     C100006                        97                   1
# 3     C100012                       570                   1
# 4     C100019                       591                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                         5      7502.00                    7502.00
# 1                         2      2400.68                    2400.68
# 2                         3       322.56                     322.56
# 3                         5       130.75                     130.75
# 4                         1        35.84                      35.84
#
#   recency_score frequency_score monetary_score RF_SCORE              segment
# 0             3               5              5       35      loyal_customers
# ...

# %%
concatenated_seg = pd.concat([df1, customer_data], axis="columns")
concatenated_seg
# Out:
#       invoice_no customer_id  gender   age  category  quantity    price  \
# 0        I138884     C241288  Female  28.0  Clothing       5.0  1500.40
# 1        I317333     C111565    Male  21.0     Shoes       3.0  1800.51
# 2        I127801     C266599    Male  20.0  Clothing       1.0   300.08
# 4        I337046     C189076  Female  53.0     Books       4.0    60.60
# 5        I227836     C657758  Female  28.0  Clothing       5.0  1500.40
# ...          ...         ...     ...   ...       ...       ...      ...
# 92254        NaN         NaN     NaN   NaN       NaN       NaN      NaN
# 92333        NaN         NaN     NaN   NaN       NaN       NaN      NaN
# 92371        NaN         NaN     NaN   NaN       NaN       NaN      NaN
# 92375        NaN         NaN     NaN   NaN       NaN       NaN      NaN
# 92409        NaN         NaN     NaN   NaN       NaN       NaN      NaN
#
#       payment_method invoice_date   shopping_mall  ...  \
# ...

# %%
concatenated_seg.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall', 'age_group',
#        'year', 'month', 'weekday', 'day', 'total_price', 'Total_Spend',
#        'customer_id', 'Days_Since_Last_Purchase', 'Total_Transactions',
#        'Total_Products_Purchased', 'Total_Spend', 'Average_Transaction_Value',
#        'recency_score', 'frequency_score', 'monetary_score', 'RF_SCORE',
#        'segment'],
#       dtype='object')

# %%
spend = concatenated_seg.groupby('segment')['total_price'].sum()
spend
# Out:
# segment
# about_to_sleep         10959019.90
# at_risk                21999273.72
# cant_loose             11032790.95
# champions              10993343.68
# hibernating            22322605.75
# loyal_customers        22365888.57
# need_attention          5399903.77
# new_customers           5605473.95
# potential_loyalists    22241110.87
# promising               5648908.96
# Name: total_price, dtype: float64

# %%
def distribution(dataframe, col):
    group_dt = dataframe.groupby(col).agg(total_price=('total_price', np.sum),
                                          quantity=('quantity', np.sum))
    group_dt['avg_revenue'] = group_dt['total_price'] / group_dt['quantity']
    return group_dt.reset_index()

# %%
d1 = distribution(concatenated_seg, 'segment')
d1
# Out:
#                segment  total_price  quantity  avg_revenue
# 0       about_to_sleep  10959019.90   19840.0   552.369955
# 1              at_risk  21999273.72   39926.0   551.001195
# 2           cant_loose  11032790.95   19813.0   556.846058
# 3            champions  10993343.68   19997.0   549.749646
# 4          hibernating  22322605.75   40053.0   557.326686
# 5      loyal_customers  22365888.57   40053.0   558.407325
# 6       need_attention   5399903.77    9870.0   547.102712
# 7        new_customers   5605473.95    9986.0   561.333262
# 8  potential_loyalists  22241110.87   39980.0   556.305925
# 9            promising   5648908.96   10004.0   564.665030

# %% [markdown]
# **Trung bình giao dịch của mỗi nhóm**

# %%
plt.figure(figsize = (17,8))

sns.barplot(x=d1['segment'], y = d1['quantity'], color = 'green')

plt.figure(figsize = (17,8))

sns.barplot(x=d1['segment'], y = d1['avg_revenue'], color = 'green')
# Out:
# <Axes: xlabel='segment', ylabel='avg_revenue'>

# %% [markdown]
# # **VIII. Demographic and Behavior Analyst based on Customer Segmentation**

# %% [markdown]
# * Chúng ta sẽ phân tích những nhóm khách hàng mua nhiều sản phẩm được phân tích theo demographic và behavior để xác định nhân khẩu học và hành vi mua hàng của từng nhóm.
# * Chọn ra 3 nhóm là Champions, Loyal_customers, and potential_loyalists

# %% [markdown]
# ## **1. Champions:**

# %%
# count total spend of segment by gender
seg_gender_spend = concatenated_seg[concatenated_seg['segment']=='champions'].groupby('gender')['total_price'].sum()

seg_gender_spend.plot.bar()
plt.title('Total Spend by Gender for Champions')
plt.xlabel('Gender')
plt.ylabel('Total Spend')
plt.show()
seg_gender_spend
# Out:
# gender
# Female    6769786.55
# Male      4223557.13
# Name: total_price, dtype: float64

# %%
# count total spend of segment by age_group

seg_age_spend = concatenated_seg[concatenated_seg['segment']=='champions'].groupby('age_group')['total_price'].sum()
seg_age_spend
seg_age_spend.plot.bar()
plt.title('Total Spend by Age Group for Champions')
plt.xlabel('Age Group')
plt.ylabel('Total Spend')
plt.show()

# %%
# prompt: count total quantity of segment by category

country_quantity = concatenated_seg[concatenated_seg['segment']=='champions'].groupby('category')['quantity'].sum()
country_quantity
country_quantity.plot.bar()
plt.title('Total Quantity by Category for Champions')
plt.xlabel('Category')
plt.ylabel('Total Quantity')
plt.show()

# %%
# prompt: count payment_method by champions

seg_payment_method = concatenated_seg[concatenated_seg['segment']=='champions'].groupby('payment_method')['payment_method'].count()
seg_payment_method
seg_payment_method.plot.bar()
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

# %%
# Create a pivot table to summarize the total price of purchases for each month
pivot_table = concatenated_seg[concatenated_seg['segment'] == 'champions'].pivot_table(values='quantity', index='month', aggfunc='sum')

# Plot the pivot table as a line chart
pivot_table.plot(kind='line', figsize=(10, 6))

# Set the title and axis labels
plt.title('Buy Trend of Champion Segment by Month in Year')
plt.xlabel('Month')
plt.ylabel('Total Price')

# Show the plot
plt.show()

# %% [markdown]
# ## **2. Loyal_customers**

# %%
# count total spend of segment by gender
seg_gender_spend = concatenated_seg[concatenated_seg['segment']=='loyal_customers'].groupby('gender')['total_price'].sum()


seg_gender_spend.plot.bar()
plt.title('Total Spend by Gender for Loyal_Customers')
plt.xlabel('Gender')
plt.ylabel('Total Spend')
plt.show()
seg_gender_spend
# Out:
# gender
# Female    13642071.93
# Male       8723816.64
# Name: total_price, dtype: float64

# %%
seg_age_spend = concatenated_seg[concatenated_seg['segment']=='loyal_customers'].groupby('age_group')['total_price'].sum()

seg_age_spend.plot.bar()
plt.title('Total Spend by Age Group for loyal_customers')
plt.xlabel('Age Group')
plt.ylabel('Total Spend')
plt.show()

seg_age_spend
# Out:
# age_group
# middle_age     6349256.25
# old_age       10339310.02
# young_age      5677322.30
# Name: total_price, dtype: float64

# %%
country_quantity = concatenated_seg[concatenated_seg['segment']=='loyal_customers'].groupby('category')['quantity'].sum()

country_quantity.plot.bar()
plt.title('Total Quantity by Category for loyal_customers')
plt.xlabel('Category')
plt.ylabel('Total Quantity')
plt.show()
country_quantity
# Out:
# category
# Books               2220.0
# Clothing           15595.0
# Cosmetics           6847.0
# Food & Beverage     6425.0
# Shoes               1771.0
# Souvenir            2285.0
# Technology           427.0
# Toys                4483.0
# Name: quantity, dtype: float64

# %%
seg_payment_method = concatenated_seg[concatenated_seg['segment']=='loyal_customers'].groupby('payment_method')['payment_method'].count()

seg_payment_method.plot.bar()
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

seg_payment_method
# Out:
# payment_method
# Cash           6181
# Credit Card    4776
# Debit Card     2791
# Name: payment_method, dtype: int64

# %%
# Create a pivot table to summarize the total price of purchases for each month
pivot_table = concatenated_seg[concatenated_seg['segment'] == 'loyal_customers'].pivot_table(values='quantity', index='month', aggfunc='sum')

# Plot the pivot table as a line chart
pivot_table.plot(kind='line', figsize=(10, 6))

# Set the title and axis labels
plt.title('Buy Trend of loyal_customers Segment by Month in Year')
plt.xlabel('Month')
plt.ylabel('Total Price')

# Show the plot
plt.show()

# %% [markdown]
# ## **3. Potential_loyalist**

# %%
seg_gender_spend = concatenated_seg[concatenated_seg['segment']=='potential_loyalists'].groupby('gender')['total_price'].sum()


seg_gender_spend.plot.bar()
plt.title('Total Spend by Gender for potential_loyalists')
plt.xlabel('Gender')
plt.ylabel('Total Spend')
plt.show()
seg_gender_spend
# Out:
# gender
# Female    13102371.41
# Male       9138739.46
# Name: total_price, dtype: float64

# %%
seg_age_spend = concatenated_seg[concatenated_seg['segment']=='potential_loyalists'].groupby('age_group')['total_price'].sum()

seg_age_spend.plot.bar()
plt.title('Total Spend by Age Group for potential_loyalists')
plt.xlabel('Age Group')
plt.ylabel('Total Spend')
plt.show()

seg_age_spend
# Out:
# age_group
# middle_age     6353135.38
# old_age       10253176.67
# young_age      5634798.82
# Name: total_price, dtype: float64

# %%
country_quantity = concatenated_seg[concatenated_seg['segment']=='potential_loyalists'].groupby('category')['quantity'].sum()

country_quantity.plot.bar()
plt.title('Total Quantity by Category for potential_loyalists')
plt.xlabel('Category')
plt.ylabel('Total Quantity')
plt.show()
country_quantity
# Out:
# category
# Books               2256.0
# Clothing           15341.0
# Cosmetics           6791.0
# Food & Beverage     6418.0
# Shoes               1824.0
# Souvenir            2233.0
# Technology           425.0
# Toys                4692.0
# Name: quantity, dtype: float64

# %%
seg_payment_method = concatenated_seg[concatenated_seg['segment']=='potential_loyalists'].groupby('payment_method')['payment_method'].count()

seg_payment_method.plot.bar()
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

seg_payment_method
# Out:
# payment_method
# Cash           6050
# Credit Card    4910
# Debit Card     2757
# Name: payment_method, dtype: int64

# %%
# Create a pivot table to summarize the total price of purchases for each month
pivot_table = concatenated_seg[concatenated_seg['segment'] == 'potential_loyalists'].pivot_table(values='quantity', index='month', aggfunc='sum')

# Plot the pivot table as a line chart
pivot_table.plot(kind='line', figsize=(10, 6))

# Set the title and axis labels
plt.title('Buy Trend of potential_loyalists Segment by Month in Year')
plt.xlabel('Month')
plt.ylabel('Total Price')

# Show the plot
plt.show()

# %% [markdown]
# ## **4. Promising**

# %%
seg_gender_spend = concatenated_seg[concatenated_seg['segment']=='promising'].groupby('gender')['total_price'].sum()


seg_gender_spend.plot.bar()
plt.title('Total Spend by Gender for promising')
plt.xlabel('Gender')
plt.ylabel('Total Spend')
plt.show()
seg_gender_spend
# Out:
# gender
# Female    3268163.54
# Male      2380745.42
# Name: total_price, dtype: float64

# %%
seg_age_spend = concatenated_seg[concatenated_seg['segment']=='promising'].groupby('age_group')['total_price'].sum()

seg_age_spend.plot.bar()
plt.title('Total Spend by Age Group for promising')
plt.xlabel('Age Group')
plt.ylabel('Total Spend')
plt.show()

seg_age_spend
# Out:
# age_group
# middle_age    1567408.96
# old_age       2589258.80
# young_age     1492241.20
# Name: total_price, dtype: float64

# %%
country_quantity = concatenated_seg[concatenated_seg['segment']=='promising'].groupby('category')['quantity'].sum()

country_quantity.plot.bar()
plt.title('Total Quantity by Category for promising')
plt.xlabel('Category')
plt.ylabel('Total Quantity')
plt.show()
country_quantity
# Out:
# category
# Books               503.0
# Clothing           3953.0
# Cosmetics          1638.0
# Food & Beverage    1662.0
# Shoes               450.0
# Souvenir            583.0
# Technology          113.0
# Toys               1102.0
# Name: quantity, dtype: float64

# %%
seg_payment_method = concatenated_seg[concatenated_seg['segment']=='promising'].groupby('payment_method')['payment_method'].count()

seg_payment_method.plot.bar()
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

seg_payment_method
# Out:
# payment_method
# Cash           1529
# Credit Card    1294
# Debit Card      640
# Name: payment_method, dtype: int64

# %%
# Create a pivot table to summarize the total price of purchases for each month
pivot_table = concatenated_seg[concatenated_seg['segment'] == 'promising'].pivot_table(values='quantity', index='month', aggfunc='sum')

# Plot the pivot table as a line chart
pivot_table.plot(kind='line', figsize=(10, 6))

# Set the title and axis labels
plt.title('Buy Trend of promising Segment by Month in Year')
plt.xlabel('Month')
plt.ylabel('Total Price')

# Show the plot
plt.show()
